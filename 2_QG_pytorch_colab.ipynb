# %% [markdown]
# <a href="https://colab.research.google.com/github/27septembre/QG_eff/blob/main/2_QG_pytorch_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # setting

# %% [markdown]
# input data: data/outputs/
#
# * training: data/training/00/  (generated by 1_qgm2_calc_eff_generate_training_data.ipynb)
# * pred: data/preds/
#
# if with noise:
# *   training: data/noise_filtered/ (generated by 5_qgm2_calc_eff_generate_noise.ipynb)
# *   pred: data/preds/

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# if running on Colab
# !git clone https://github.com/27septembre/QG_eff/
# Out:
# Cloning into 'QG_eff'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 83 (delta 19), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (83/83), 92.90 MiB | 6.40 MiB/s, done.

# %%
# data location
# running locally
#data_dir='data/'

# if running on Colab
data_dir='QG_eff/data/'

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# # Preparation

# %% [markdown]
# ## Data loaders

# %%
# NOTE: would be better to pull this out from qg_parameters.F90
layers, nx, ny = 3, 513, 513

Lx, Ly = 3840.0e5, 3840.0e5      # lengths (in cm)
scale = Lx / (nx - 1)               # scaling factor (T = L = sc)  #750000
x_vec, y_vec = np.linspace(0, Lx, nx), np.linspace(0, Ly, ny)
H = [0.25e5, 0.75e5, 3.0e5]      # layer depths (in cm)
avg_period = 5000.0 * 3600 * 24  # averaging period (*_int.data is time-integrated)
avg_period_nondim = avg_period / scale

# %%
#  adjust data location/
def read_data(varnn,nlyr,nre,fname,nl=0):
    if varnn =='div':
          if nl == 0:
            return np.load(data_dir+'training/%s/div_uq_%s_80.npy'%(nre,fname))[nlyr]
          else:
            return np.load(data_dir+'noise_filtered/div_uq_%s_80_noise%s.npy'%(fname,"{:02}".format(int(nl * 10))))[nlyr]
    elif varnn =='grad' or varnn =='uvq':
        if nl == 0:
            ff = np.load(data_dir+'training/%s/%s_%s_80.npz'%(nre,varnn,fname))
        else:
            ff = np.load(data_dir+'noise_filtered/%s_%s_80_noise%s.npz'%(varnn,fname,"{:02}".format(int(nl * 10))))
        return ff[ff.files[0]][nlyr],ff[ff.files[1]][nlyr]
    else:
        pp= np.fromfile(data_dir+'outputs/%s_int.dat'%(varnn),
                            dtype=np.float64).reshape(layers, nx, ny) / avg_period_nondim
        return pp[nlyr]

# %%
# divide into 40x40 patches
def get_data(var_1):
    nt=40
    var2= np.zeros( (100**2,nt,nt) )
    stride =6
    ni=0

    for i in range( 0, var_1.shape[1]-nt+1, stride):
        for j in range( 0, var_1.shape[0]-nt+1, stride ):
            var2[ni] = var_1[j:j+nt,i:i+nt]
            ni+=1
        if var_1.shape[0]-(j+nt) != 0:
            var2[ni] = var_1[-nt:var_1.shape[1],i:i+nt]
            ni+=1

    if var_1.shape[1]-(i+nt) != 0 :
        for j in range( 0, var_1.shape[0]-nt+1, stride ):   # loop through points in y
            var2[ni] = var_1[j:j+nt,-nt:var_1.shape[0]]
            ni+=1
        if var_1.shape[0]-(j+nt) != 0:
            var2[ni] = var_1[-nt:var_1.shape[1],i:i+nt]
            ni+=1

    var2=var2[:ni]
    return var2

# %%
# 1 input to 1 output
def load_dataT(p_1,s_1,rni,batchsize):
    nt=40

    mu1, sigma1 = np.mean( p_1 ), np.std( p_1 )
    mu2, sigma2 = np.mean( s_1 ), np.std( s_1 )
    scalings = [mu1, sigma1, mu2, sigma2]

    p_input = (p_1-mu1)/sigma1
    S_out = (s_1-mu2)/sigma2

    xTrain, xVal, yTrain, yVal= train_test_split( p_input, S_out, test_size=0.2, random_state=rni, shuffle=True)

    xTrain = np.reshape(xTrain, (-1,1, nt, nt))
    xVal = np.reshape(xVal, (-1, 1,nt, nt))

    yTrain = np.reshape(yTrain, (-1, nt * nt))  # For CNNs #1
    yVal = np.reshape(yVal, (-1, nt * nt))

    dataset = torch.utils.data.TensorDataset(torch.from_numpy(xTrain).float(),torch.from_numpy(yTrain).float())
    train_loader=torch.utils.data.DataLoader(dataset , batch_size=batchsize, shuffle=True, num_workers=2)
    dataset = torch.utils.data.TensorDataset(torch.from_numpy(xVal).float(),torch.from_numpy(yVal).float())
    val_loader=torch.utils.data.DataLoader(dataset , batch_size=batchsize, shuffle=True, num_workers=2)

    return train_loader,val_loader, scalings

# %%
# 1 input to 2 outputs
def load_dataT2(p_1,s_1,s_2,rni,batchsize):
    nt=40

    mu1, sigma1 = np.mean( p_1 ), np.std( p_1 )
    mu2, sigma2 = np.mean( s_1 ), np.std( s_1 )
    mu3, sigma3 = np.mean( s_2 ), np.std( s_2 )
    scalings1 = [mu1, sigma1, mu2, sigma2]
    scalings2 = [mu1, sigma1, mu3, sigma3]

    p_input = (p_1-mu1)/sigma1
    s_out1 = (s_1-mu2)/sigma2
    s_out2 = (s_2-mu3)/sigma3
    S_out = np.stack((s_out1,s_out2),axis=3)

    xTrain, xVal, yTrain, yVal= train_test_split( p_input, S_out, test_size=0.2, random_state=rni, shuffle=True)

    xTrain = np.reshape(xTrain, (-1,1, nt, nt))
    xVal = np.reshape(xVal, (-1, 1,nt, nt))

    yTrain = np.reshape(yTrain, (-1, nt * nt*2))  # For CNNs #1
    yVal = np.reshape(yVal, (-1, nt * nt*2))

    dataset = torch.utils.data.TensorDataset(torch.from_numpy(xTrain).float(),torch.from_numpy(yTrain).float())
    train_loader=torch.utils.data.DataLoader(dataset , batch_size=batchsize, shuffle=True, num_workers=2)
    dataset = torch.utils.data.TensorDataset(torch.from_numpy(xVal).float(),torch.from_numpy(yVal).float())
    val_loader=torch.utils.data.DataLoader(dataset , batch_size=batchsize, shuffle=True, num_workers=2)

    return train_loader,val_loader,scalings1,scalings2

# %% [markdown]
# ## Functions

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=1e-6, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement.
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %% [markdown]
# ## Model classes

# %%
class train_model(nn.Module):
    def __init__(self,n_feature,n_out):
        super(train_model, self).__init__()
        self.conv1 = nn.Conv2d(n_feature, 16, 8,stride=1, padding='valid')
        self.conv2 = nn.Conv2d(16, 8, 4, padding='valid')
        self.conv3 = nn.Conv2d(8, 8, 4, padding='valid')
        self.fc1 = nn.Linear(1352, 40*40*n_out) #8*13*13

    def forward(self, x):
        x = F.selu(self.conv1(x))
        x = F.selu(self.conv2(x))
        x = F.max_pool2d(F.selu(self.conv3(x)),2)
        x = x.view(-1, 1352)
        x = self.fc1(x)
        return x

# %% [markdown]
# ## Training processes

# %%
def make_train_step(model, loss_fn, optimizer):
    # Builds function that performs a step in the train loop
    def train_step(x, y):
        # Sets model to TRAIN mode
        model.train()
        # Makes predictions
        yhat = model(x)
        # Computes loss
        loss = loss_fn(y, yhat)
        # Computes gradients
        loss.backward()
        # Updates parameters and zeroes gradients
        optimizer.step()
        optimizer.zero_grad()
        # Returns the loss
        return loss.item()

    # Returns the function that will be called inside the train loop
    return train_step

# %%
def trainig_process(model,train_loader,val_loader):
    lr = 1e-4
    n_epochs = 1000

    loss_fn = nn.MSELoss(reduction='mean')#
    optimizer =  torch.optim.Adam(model.parameters(), lr=lr)

    # Creates the train_step function for our model, loss function and optimizer
    losses = []
    val_losses = []
    train_step = make_train_step(model, loss_fn, optimizer)
    early_stopping = EarlyStopping(patience=20, verbose=True)

    for epoch in range(n_epochs):
        losses_e = []
        val_losses_e = []
        for x_batch, y_batch in train_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            loss = train_step(x_batch, y_batch)
            losses_e.append(loss)

        with torch.no_grad():
            for x_val, y_val in val_loader:
                x_val = x_val.to(device)
                y_val = y_val.to(device)

                model.eval()

                yhat = model(x_val)
                val_loss = loss_fn(y_val, yhat)
                val_losses_e.append(val_loss.item())

        losses.append(np.average(losses_e))
        val_losses.append(np.average(val_losses_e))

        early_stopping(np.average(val_losses_e), model)

        if early_stopping.early_stop:
            print("Early stopping")
            break
        print('Epoch : ',epoch+1, '\t', 'loss :', np.average(losses_e),'loss_val :', np.average(val_losses_e))

    model.load_state_dict(torch.load('checkpoint.pt'))

    plt.plot(losses, label='Training loss')
    plt.plot(val_losses, label='Validation loss')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## Predictions

# %%
# 1 input to 1 output
def makePreds_1to1_all(x, scl, model) :
    nt=40
    scalings =scl
    shpx=x.shape[1]
    shpy=x.shape[0]

    mu1, sigma1, mu2, sigma2 = scalings[0], scalings[1], scalings[2], scalings[3]
    psiFilt = (x - mu1) / sigma1

    SPred = np.zeros( (shpy,shpx) )
    mask = np.zeros( (shpy,shpx) )

    stride = 2
    for i in range( 0, shpx-nt+1, stride):
        for j in range( 0, shpy-nt+1, stride ):
            tt= torch.from_numpy(psiFilt[j:j+nt,i:i+nt].reshape(-1,1,nt,nt)).float()
            SPred[j:j+nt,i:i+nt] += (model(tt.to(device)).cpu().detach().numpy()).reshape(nt,nt)
            mask[j:j+nt,i:i+nt] += 1

    SPred = np.divide( SPred, mask )
    SPred = SPred * sigma2 + mu2

    return SPred

# %%
# 1 input to 2 outputs
def makePreds_1to2_all(x,scl,scl2, model) :
    nt=40
    scalings =scl
    scalings2=scl2
    shpx=x.shape[1]
    shpy=x.shape[0]

    mu1, sigma1, mu2, sigma2 = scalings[0], scalings[1], scalings[2], scalings[3]
    p_input= (x - mu1) / sigma1

    SPred =np.zeros( (2,shpy,shpx))
    mask = np.zeros( (1,shpy,shpx) )

    stride = 2
    for i in range( 0, shpx-nt+1, stride):   # loop through points in x
       #print(i)
       for j in range( 0, shpy-nt+1, stride ):   # loop through points in y
            tt= torch.from_numpy(p_input[j:j+nt,i:i+nt].reshape(-1,1,nt,nt)).float()
            pred = (model(tt.to(device))[0].cpu().detach().numpy()).reshape((nt,nt,2))
            SPred[0,j:j+nt,i:i+nt] += pred[:,:,0]
            SPred[1,j:j+nt,i:i+nt] += pred[:,:,1]
            mask[0,j:j+nt,i:i+nt] += 1

    SPred = np.divide( SPred, mask )
    SP_x = SPred[0,:,:] * sigma2 + mu2
    SP_y = SPred[1,:,:] * scalings2[3] + scalings2[2]

    return SP_x,SP_y

# %% [markdown]
# # One input

# %%
nre='00' # training data
nre2='00' # predict data
batchsize = 64
nlayer=0  # training layer
nl=0  # noise level

fileloc=data_dir+'preds/'
if not os.path.exists(fileloc):
  os.mkdir(fileloc)

for kw in ['00']: # default setting
    if not os.path.exists(fileloc+kw):
        os.mkdir(fileloc+kw)
    filename=fileloc+'%s/'%(kw)

    for var1 in ['psi']:# "q","rel"
        for vn in ['div']:#'div','uvq','grad'
              for f in ['empb']:# "em","eb"
                    for rni in range(30,31):  # random seeds 30-50
                        print(kw,nre,var1,vn,f,rni)
                        if kw == '00':
                            input_d = get_data(read_data(var1,nlayer,nre,f))
                            if vn == 'div':
                                empb = get_data(read_data(vn,nlayer,nre,f))
                            else:
                                gd_u = get_data(read_data(vn,nlayer,nre,f)[0])
                                gd_v = get_data(read_data(vn,nlayer,nre,f)[1])
                        else:
                            print('non')

                        if vn == 'div':
                            if not os.path.exists(filename+'%s/Pr_%s_%s_%s_%s_%s.npy'%(nlayer,vn,f,nre2,var1,rni)):
                                train_loader,val_loader, scalings=load_dataT(input_d,empb,rni,batchsize)
                                model = train_model(n_feature=1,n_out=1).to(device)
                                trainig_process(model,train_loader,val_loader)
                                if not os.path.exists(filename+'models'):
                                    os.mkdir(filename+'models')
                                #torch.save(model, filename+'models/%s_%s_%s_%s.pth'%(vn,f,var1,rni))

                                for nly in range(1):
                                    input_t = read_data(var1,nly,nre2,f)
                                    Spr=makePreds_1to1_all(input_t,scalings,model)
                                    if not os.path.exists(filename+'%s'%(nly)):
                                        os.mkdir(filename+'%s'%(nly))
                                    np.save(filename+'%s/Pr_%s_%s_%s_%s_%s'%(nly,vn,f,nre2,var1,rni),Spr)
                        else:
                            if not os.path.exists(filename+'%s/Pr_%s_%s_%s_%s_%s.npz'%(nlayer,vn,f,nre2,var1,rni)):
                                train_loader,val_loader, scalings1,scalings2=load_dataT2(input_d,gd_u,gd_v,rni,batchsize)
                                model2 = train_model(n_feature=1,n_out=2).to(device)
                                trainig_process(model2,train_loader,val_loader)
                                if not os.path.exists(filename+'models'):
                                    os.mkdir(filename+'models')
                                #torch.save(model2, filename+'models/%s_%s_%s_%s.pth'%(vn,f,var1,rni))

                                for nly in range(1):
                                    input_t = read_data(var1,nly,nre2,f)
                                    Spr_u,Spr_v=makePreds_1to2_all(input_t,scalings1,scalings2,model2)
                                    if not os.path.exists(filename+'%s'%(nly)):
                                        os.mkdir(filename+'%s'%(nly))
                                    np.savez(filename+'%s/Pr_%s_%s_%s_%s_%s'%(nly,vn,f,nre2,var1,rni),Spr_u,Spr_v)
# Out:
# 00 00 psi div empb 30
# Validation loss decreased (inf --> 0.843155).  Saving model ...
# Epoch :  1 	 loss : 1.0378702125046402 loss_val : 0.8431547850370407
# Validation loss decreased (0.843155 --> 0.787316).  Saving model ...
# Epoch :  2 	 loss : 1.0006370812654495 loss_val : 0.7873161051422357
# Validation loss decreased (0.787316 --> 0.731420).  Saving model ...
# Epoch :  3 	 loss : 0.9132941686548293 loss_val : 0.7314202390611172
# Validation loss decreased (0.731420 --> 0.714042).  Saving model ...
# Epoch :  4 	 loss : 0.8596188039518893 loss_val : 0.7140419509261846
# Validation loss decreased (0.714042 --> 0.703266).  Saving model ...
# Epoch :  5 	 loss : 0.8322740082163363 loss_val : 0.7032660249620676
# Validation loss decreased (0.703266 --> 0.692464).  Saving model ...
# Epoch :  6 	 loss : 0.8122985272668302 loss_val : 0.6924636192619801
# Validation loss decreased (0.692464 --> 0.689269).  Saving model ...
# Epoch :  7 	 loss : 0.8010600770357996 loss_val : 0.6892687395215035
# Validation loss decreased (0.689269 --> 0.678005).  Saving model ...
# Epoch :  8 	 loss : 0.7870406853035092 loss_val : 0.6780048351734876
# Validation loss decreased (0.678005 --> 0.670671).  Saving model ...
# Epoch :  9 	 loss : 0.7771757540293038 loss_val : 0.6706710685044527
# Validation loss decreased (0.670671 --> 0.664010).  Saving model ...
# Epoch :  10 	 loss : 0.7671598085202277 loss_val : 0.6640100762248039
# Validation loss decreased (0.664010 --> 0.655965).  Saving model ...
# Epoch :  11 	 loss : 0.758569266833365 loss_val : 0.6559647619724274
# Validation loss decreased (0.655965 --> 0.654337).  Saving model ...
# Epoch :  12 	 loss : 0.7513580190017819 loss_val : 0.654336617141962
# Validation loss decreased (0.654337 --> 0.652240).  Saving model ...
# Epoch :  13 	 loss : 0.744859172590077 loss_val : 0.6522398300468921
# Validation loss decreased (0.652240 --> 0.646788).  Saving model ...
# Epoch :  14 	 loss : 0.7388252574950457 loss_val : 0.6467877566814423
# Validation loss decreased (0.646788 --> 0.639076).  Saving model ...
# Epoch :  15 	 loss : 0.7334973396733403 loss_val : 0.639076429605484
# Validation loss decreased (0.639076 --> 0.636223).  Saving model ...
# Epoch :  16 	 loss : 0.7261112375184894 loss_val : 0.6362233575433492
# Validation loss decreased (0.636223 --> 0.633440).  Saving model ...
# Epoch :  17 	 loss : 0.7216014692559838 loss_val : 0.6334395922720433
# Validation loss decreased (0.633440 --> 0.629093).  Saving model ...
# Epoch :  18 	 loss : 0.715706869866699 loss_val : 0.6290933474898338
# Validation loss decreased (0.629093 --> 0.624649).  Saving model ...
# Epoch :  19 	 loss : 0.7110785287804902 loss_val : 0.6246487960219383
# Validation loss decreased (0.624649 --> 0.621474).  Saving model ...
# Epoch :  20 	 loss : 0.7050920139066875 loss_val : 0.6214739046990871
# Validation loss decreased (0.621474 --> 0.620224).  Saving model ...
# Epoch :  21 	 loss : 0.6989300203509629 loss_val : 0.6202237419784069
# EarlyStopping counter: 1 out of 20
# Epoch :  22 	 loss : 0.6951797806657851 loss_val : 0.6250867448747158
# Validation loss decreased (0.620224 --> 0.618211).  Saving model ...
# Epoch :  23 	 loss : 0.6911240837536752 loss_val : 0.6182112701237201
# Validation loss decreased (0.618211 --> 0.614438).  Saving model ...
# Epoch :  24 	 loss : 0.685819117538631 loss_val : 0.6144380405545234
# Validation loss decreased (0.614438 --> 0.614144).  Saving model ...
# Epoch :  25 	 loss : 0.6825307097751647 loss_val : 0.6141439534723758
# Validation loss decreased (0.614144 --> 0.610350).  Saving model ...
# Epoch :  26 	 loss : 0.6781358853913844 loss_val : 0.6103499609977007
# EarlyStopping counter: 1 out of 20
# Epoch :  27 	 loss : 0.6739706793799997 loss_val : 0.6139013938605785
# Validation loss decreased (0.610350 --> 0.606296).  Saving model ...
# Epoch :  28 	 loss : 0.6708741371519864 loss_val : 0.6062960498034954
# Validation loss decreased (0.606296 --> 0.604906).  Saving model ...
# Epoch :  29 	 loss : 0.6660451130010188 loss_val : 0.6049059748649597
# Validation loss decreased (0.604906 --> 0.603592).  Saving model ...
# Epoch :  30 	 loss : 0.6617492010816932 loss_val : 0.6035920590162277
# Validation loss decreased (0.603592 --> 0.603133).  Saving model ...
# Epoch :  31 	 loss : 0.6587470123544336 loss_val : 0.6031326141208411
# EarlyStopping counter: 1 out of 20
# Epoch :  32 	 loss : 0.6543271822389215 loss_val : 0.6035540018230676
# Validation loss decreased (0.603133 --> 0.599646).  Saving model ...
# Epoch :  33 	 loss : 0.6512892284430564 loss_val : 0.5996462568640709
# Validation loss decreased (0.599646 --> 0.599617).  Saving model ...
# Epoch :  34 	 loss : 0.6508719122037292 loss_val : 0.5996169794350863
# Validation loss decreased (0.599617 --> 0.596864).  Saving model ...
# Epoch :  35 	 loss : 0.6460352181456983 loss_val : 0.596863504499197
# EarlyStopping counter: 1 out of 20
# Epoch :  36 	 loss : 0.6457199370488524 loss_val : 0.5989765476435422
# Validation loss decreased (0.596864 --> 0.596423).  Saving model ...
# Epoch :  37 	 loss : 0.6398754404857755 loss_val : 0.5964231789112091
# Validation loss decreased (0.596423 --> 0.592196).  Saving model ...
# Epoch :  38 	 loss : 0.6389184669591487 loss_val : 0.5921960830688476
# EarlyStopping counter: 1 out of 20
# Epoch :  39 	 loss : 0.6342912936583162 loss_val : 0.5949052130803466
# Validation loss decreased (0.592196 --> 0.590886).  Saving model ...
# Epoch :  40 	 loss : 0.6325935071334243 loss_val : 0.5908860454335809
# EarlyStopping counter: 1 out of 20
# Epoch :  41 	 loss : 0.6309908627066761 loss_val : 0.5941225439310074
# Validation loss decreased (0.590886 --> 0.588583).  Saving model ...
# Epoch :  42 	 loss : 0.6285984333604574 loss_val : 0.588583268225193
# EarlyStopping counter: 1 out of 20
# Epoch :  43 	 loss : 0.6264720972627401 loss_val : 0.6036278065294027
# Validation loss decreased (0.588583 --> 0.587711).  Saving model ...
# Epoch :  44 	 loss : 0.6226126979105174 loss_val : 0.587710528075695
# Validation loss decreased (0.587711 --> 0.581728).  Saving model ...
# Epoch :  45 	 loss : 0.6224640597123653 loss_val : 0.5817283540964127
# EarlyStopping counter: 1 out of 20
# Epoch :  46 	 loss : 0.6188063186127692 loss_val : 0.5867312610149383
# Validation loss decreased (0.581728 --> 0.581674).  Saving model ...
# Epoch :  47 	 loss : 0.6168719467706978 loss_val : 0.581673613935709
# EarlyStopping counter: 1 out of 20
# Epoch :  48 	 loss : 0.6156614400446415 loss_val : 0.581881656497717
# EarlyStopping counter: 2 out of 20
# Epoch :  49 	 loss : 0.6134075439535082 loss_val : 0.5849705331027508
# Validation loss decreased (0.581674 --> 0.580484).  Saving model ...
# Epoch :  50 	 loss : 0.6107171127572656 loss_val : 0.5804842468351126
# EarlyStopping counter: 1 out of 20
# Epoch :  51 	 loss : 0.6089899068698287 loss_val : 0.5816540252417326
# EarlyStopping counter: 2 out of 20
# Epoch :  52 	 loss : 0.6076945097185671 loss_val : 0.5834912769496441
# Validation loss decreased (0.580484 --> 0.579735).  Saving model ...
# Epoch :  53 	 loss : 0.6073550404049456 loss_val : 0.5797352295368909
# Validation loss decreased (0.579735 --> 0.579316).  Saving model ...
# Epoch :  54 	 loss : 0.6035368663258851 loss_val : 0.579316034168005
# Validation loss decreased (0.579316 --> 0.576726).  Saving model ...
# Epoch :  55 	 loss : 0.6022379705682397 loss_val : 0.5767264790832997
# Validation loss decreased (0.576726 --> 0.573715).  Saving model ...
# Epoch :  56 	 loss : 0.6011753731407226 loss_val : 0.5737150706350803
# EarlyStopping counter: 1 out of 20
# Epoch :  57 	 loss : 0.5984983530361205 loss_val : 0.5758241195231676
# EarlyStopping counter: 2 out of 20
# Epoch :  58 	 loss : 0.5975250367075204 loss_val : 0.574200888723135
# Validation loss decreased (0.573715 --> 0.572738).  Saving model ...
# Epoch :  59 	 loss : 0.5960787554271519 loss_val : 0.5727377131581306
# EarlyStopping counter: 1 out of 20
# Epoch :  60 	 loss : 0.5943407226819545 loss_val : 0.5826378040015697
# EarlyStopping counter: 2 out of 20
# Epoch :  61 	 loss : 0.592885195184499 loss_val : 0.5728290408849717
# EarlyStopping counter: 3 out of 20
# Epoch :  62 	 loss : 0.5907448419369757 loss_val : 0.5777615912258625
# EarlyStopping counter: 4 out of 20
# Epoch :  63 	 loss : 0.5909190856851637 loss_val : 0.5737255699932575
# Validation loss decreased (0.572738 --> 0.570359).  Saving model ...
# Epoch :  64 	 loss : 0.5889715421944857 loss_val : 0.5703588362783194
# Validation loss decreased (0.570359 --> 0.570086).  Saving model ...
# Epoch :  65 	 loss : 0.587265913002193 loss_val : 0.5700864888727665
# Validation loss decreased (0.570086 --> 0.565676).  Saving model ...
# Epoch :  66 	 loss : 0.5857047659344972 loss_val : 0.565676112100482
# EarlyStopping counter: 1 out of 20
# Epoch :  67 	 loss : 0.584024451021105 loss_val : 0.5714400470256805
# EarlyStopping counter: 2 out of 20
# Epoch :  68 	 loss : 0.584456152562052 loss_val : 0.5667317256331443
# Validation loss decreased (0.565676 --> 0.561052).  Saving model ...
# Epoch :  69 	 loss : 0.5823028147220611 loss_val : 0.561052068322897
# EarlyStopping counter: 1 out of 20
# Epoch :  70 	 loss : 0.581685469346121 loss_val : 0.5639582302421331
# EarlyStopping counter: 2 out of 20
# Epoch :  71 	 loss : 0.5779445931315422 loss_val : 0.5741270657628774
# Validation loss decreased (0.561052 --> 0.559970).  Saving model ...
# Epoch :  72 	 loss : 0.5785298156086356 loss_val : 0.5599698014557362
# EarlyStopping counter: 1 out of 20
# Epoch :  73 	 loss : 0.5742098201066256 loss_val : 0.5616290733218193
# EarlyStopping counter: 2 out of 20
# Epoch :  74 	 loss : 0.5736186577938497 loss_val : 0.5645659033209085
# EarlyStopping counter: 3 out of 20
# Epoch :  75 	 loss : 0.5723578262142837 loss_val : 0.5632342740893364
# EarlyStopping counter: 4 out of 20
# Epoch :  76 	 loss : 0.5732988000847399 loss_val : 0.563643890619278
# EarlyStopping counter: 5 out of 20
# Epoch :  77 	 loss : 0.570038013253361 loss_val : 0.5642779618501663
# Validation loss decreased (0.559970 --> 0.559357).  Saving model ...
# Epoch :  78 	 loss : 0.5679553931578993 loss_val : 0.5593573208898306
# EarlyStopping counter: 1 out of 20
# Epoch :  79 	 loss : 0.5678705628961325 loss_val : 0.5605820517987012
# Validation loss decreased (0.559357 --> 0.557870).  Saving model ...
# Epoch :  80 	 loss : 0.5644308358430863 loss_val : 0.5578701533377171
# EarlyStopping counter: 1 out of 20
# Epoch :  81 	 loss : 0.5663821971043944 loss_val : 0.5606411531567573
# Validation loss decreased (0.557870 --> 0.555453).  Saving model ...
# Epoch :  82 	 loss : 0.5626498442143202 loss_val : 0.5554527930915356
# EarlyStopping counter: 1 out of 20
# Epoch :  83 	 loss : 0.560709232185036 loss_val : 0.5610834557563067
# EarlyStopping counter: 2 out of 20
# Epoch :  84 	 loss : 0.5614547066390514 loss_val : 0.5562301520258188
# EarlyStopping counter: 3 out of 20
# Epoch :  85 	 loss : 0.5603603666648269 loss_val : 0.5559248812496662
# Validation loss decreased (0.555453 --> 0.552211).  Saving model ...
# Epoch :  86 	 loss : 0.558558753412217 loss_val : 0.5522105187177658
# EarlyStopping counter: 1 out of 20
# Epoch :  87 	 loss : 0.5586107642389834 loss_val : 0.5609934374690055
# EarlyStopping counter: 2 out of 20
# Epoch :  88 	 loss : 0.5574601199477911 loss_val : 0.5546777650713921
# EarlyStopping counter: 3 out of 20
# Epoch :  89 	 loss : 0.5558122898917646 loss_val : 0.5553006095811724
# Validation loss decreased (0.552211 --> 0.550815).  Saving model ...
# Epoch :  90 	 loss : 0.5549496100284159 loss_val : 0.550814650952816
# EarlyStopping counter: 1 out of 20
# Epoch :  91 	 loss : 0.5531758784316481 loss_val : 0.5540918320417404
# EarlyStopping counter: 2 out of 20
# Epoch :  92 	 loss : 0.5519390542525798 loss_val : 0.5539346545934677
# Validation loss decreased (0.550815 --> 0.549389).  Saving model ...
# Epoch :  93 	 loss : 0.5522064130753279 loss_val : 0.5493888832628727
# Validation loss decreased (0.549389 --> 0.548829).  Saving model ...
# Epoch :  94 	 loss : 0.5514885172713548 loss_val : 0.5488286025822162
# EarlyStopping counter: 1 out of 20
# Epoch :  95 	 loss : 0.549031166639179 loss_val : 0.5498065605759621
# EarlyStopping counter: 2 out of 20
# Epoch :  96 	 loss : 0.5484380150213838 loss_val : 0.5618626236915588
# EarlyStopping counter: 3 out of 20
# Epoch :  97 	 loss : 0.5461955004371702 loss_val : 0.5513970088213682
# EarlyStopping counter: 4 out of 20
# Epoch :  98 	 loss : 0.5449722401797772 loss_val : 0.5491723850369453
# Validation loss decreased (0.548829 --> 0.546129).  Saving model ...
# Epoch :  99 	 loss : 0.5419685583561659 loss_val : 0.5461288161575795
# EarlyStopping counter: 1 out of 20
# Epoch :  100 	 loss : 0.545684649515897 loss_val : 0.546601414307952
# EarlyStopping counter: 2 out of 20
# Epoch :  101 	 loss : 0.543261584918946 loss_val : 0.5491217821836472
# EarlyStopping counter: 3 out of 20
# Epoch :  102 	 loss : 0.5409848012030125 loss_val : 0.5481253195554018
# EarlyStopping counter: 4 out of 20
# Epoch :  103 	 loss : 0.5423529437743128 loss_val : 0.54969162940979
# EarlyStopping counter: 5 out of 20
# Epoch :  104 	 loss : 0.539572371263057 loss_val : 0.5462314330041409
# EarlyStopping counter: 6 out of 20
# Epoch :  105 	 loss : 0.5355086819734425 loss_val : 0.5533286206424236
# EarlyStopping counter: 7 out of 20
# Epoch :  106 	 loss : 0.537564636208117 loss_val : 0.5483197443187237
# EarlyStopping counter: 8 out of 20
# Epoch :  107 	 loss : 0.5365858559496701 loss_val : 0.5473212398588657
# Validation loss decreased (0.546129 --> 0.542433).  Saving model ...
# Epoch :  108 	 loss : 0.5359723132103682 loss_val : 0.5424333736300468
# EarlyStopping counter: 1 out of 20
# Epoch :  109 	 loss : 0.5340414518490434 loss_val : 0.5428203266113997
# EarlyStopping counter: 2 out of 20
# Epoch :  110 	 loss : 0.5332129960879683 loss_val : 0.5470394268631935
# EarlyStopping counter: 3 out of 20
# Epoch :  111 	 loss : 0.5302336675114929 loss_val : 0.5475292854011059
# EarlyStopping counter: 4 out of 20
# Epoch :  112 	 loss : 0.5320869387127459 loss_val : 0.5431203439831733
# EarlyStopping counter: 5 out of 20
# Epoch :  113 	 loss : 0.5280778641812504 loss_val : 0.5496750578284264
# EarlyStopping counter: 6 out of 20
# Epoch :  114 	 loss : 0.5307904932647943 loss_val : 0.5466305319219827
# EarlyStopping counter: 7 out of 20
# Epoch :  115 	 loss : 0.5279442604631186 loss_val : 0.5444632824510336
# EarlyStopping counter: 8 out of 20
# Epoch :  116 	 loss : 0.5251840420067311 loss_val : 0.543107271939516
# Validation loss decreased (0.542433 --> 0.542272).  Saving model ...
# Epoch :  117 	 loss : 0.5285886880010366 loss_val : 0.5422720912843942
# Validation loss decreased (0.542272 --> 0.540203).  Saving model ...
# Epoch :  118 	 loss : 0.5251225471496582 loss_val : 0.5402032345533371
# EarlyStopping counter: 1 out of 20
# Epoch :  119 	 loss : 0.5241025539115072 loss_val : 0.5421064712107182
# EarlyStopping counter: 2 out of 20
# Epoch :  120 	 loss : 0.5244372961111367 loss_val : 0.5517717659473419
# EarlyStopping counter: 3 out of 20
# Epoch :  121 	 loss : 0.5233891655690968 loss_val : 0.5422348879277706
# Validation loss decreased (0.540203 --> 0.539921).  Saving model ...
# Epoch :  122 	 loss : 0.5188168505672366 loss_val : 0.539921035245061
# EarlyStopping counter: 1 out of 20
# Epoch :  123 	 loss : 0.5191751121543348 loss_val : 0.5457008652389049
# Validation loss decreased (0.539921 --> 0.539687).  Saving model ...
# Epoch :  124 	 loss : 0.5165250930935145 loss_val : 0.5396873913705349
# EarlyStopping counter: 1 out of 20
# Epoch :  125 	 loss : 0.5168319537770003 loss_val : 0.5399065237492323
# Validation loss decreased (0.539687 --> 0.535044).  Saving model ...
# Epoch :  126 	 loss : 0.5176766028627753 loss_val : 0.5350440088659525
# EarlyStopping counter: 1 out of 20
# Epoch :  127 	 loss : 0.5152688759379089 loss_val : 0.5403174933046102
# EarlyStopping counter: 2 out of 20
# Epoch :  128 	 loss : 0.5149490377865732 loss_val : 0.5372125692665577
# EarlyStopping counter: 3 out of 20
# Epoch :  129 	 loss : 0.5125446559861302 loss_val : 0.5398101821541786
# EarlyStopping counter: 4 out of 20
# Epoch :  130 	 loss : 0.5136201230343431 loss_val : 0.5369418755173683
# EarlyStopping counter: 5 out of 20
# Epoch :  131 	 loss : 0.510641079582274 loss_val : 0.5385325334966182
# EarlyStopping counter: 6 out of 20
# Epoch :  132 	 loss : 0.508410464040935 loss_val : 0.5397657183930278
# EarlyStopping counter: 7 out of 20
# Epoch :  133 	 loss : 0.5096317767165601 loss_val : 0.5386125862598419
# EarlyStopping counter: 8 out of 20
# Epoch :  134 	 loss : 0.5075624732300639 loss_val : 0.5395353142172098
# EarlyStopping counter: 9 out of 20
# Epoch :  135 	 loss : 0.5066542193759233 loss_val : 0.5444041881710291
# EarlyStopping counter: 10 out of 20
# Epoch :  136 	 loss : 0.5050869323778897 loss_val : 0.5399409525096417
# EarlyStopping counter: 11 out of 20
# Epoch :  137 	 loss : 0.505514218378812 loss_val : 0.5428298922255635
# EarlyStopping counter: 12 out of 20
# Epoch :  138 	 loss : 0.5047033648006618 loss_val : 0.5375531665980816
# EarlyStopping counter: 13 out of 20
# Epoch :  139 	 loss : 0.5010945324786007 loss_val : 0.5370472993701696
# EarlyStopping counter: 14 out of 20
# Epoch :  140 	 loss : 0.5056870812550187 loss_val : 0.5454320773482323
# EarlyStopping counter: 15 out of 20
# Epoch :  141 	 loss : 0.5032934419345111 loss_val : 0.5353317335247993
# EarlyStopping counter: 16 out of 20
# Epoch :  142 	 loss : 0.5008540900424123 loss_val : 0.5375999361276627
# EarlyStopping counter: 17 out of 20
# Epoch :  143 	 loss : 0.500320132356137 loss_val : 0.5446661293506623
# EarlyStopping counter: 18 out of 20
# Epoch :  144 	 loss : 0.4991855593863875 loss_val : 0.5547605969011784
# Validation loss decreased (0.535044 --> 0.532310).  Saving model ...
# Epoch :  145 	 loss : 0.49988424787297847 loss_val : 0.532310294546187
# EarlyStopping counter: 1 out of 20
# Epoch :  146 	 loss : 0.49551794584840536 loss_val : 0.5370692439377308
# Validation loss decreased (0.532310 --> 0.532235).  Saving model ...
# Epoch :  147 	 loss : 0.49577986216172576 loss_val : 0.5322352174669505
# EarlyStopping counter: 1 out of 20
# Epoch :  148 	 loss : 0.4938938989769667 loss_val : 0.533715270832181
# EarlyStopping counter: 2 out of 20
# Epoch :  149 	 loss : 0.4919720913283527 loss_val : 0.5352152165025472
# Validation loss decreased (0.532235 --> 0.531068).  Saving model ...
# Epoch :  150 	 loss : 0.49270190028473737 loss_val : 0.5310679413378239
# EarlyStopping counter: 1 out of 20
# Epoch :  151 	 loss : 0.4923932053148746 loss_val : 0.54266357421875
# EarlyStopping counter: 2 out of 20
# Epoch :  152 	 loss : 0.493096125125885 loss_val : 0.5386970847845077
# EarlyStopping counter: 3 out of 20
# Epoch :  153 	 loss : 0.48786372076719997 loss_val : 0.5350252360105514
# EarlyStopping counter: 4 out of 20
# Epoch :  154 	 loss : 0.49190862716641276 loss_val : 0.5406507253646851
# EarlyStopping counter: 5 out of 20
# Epoch :  155 	 loss : 0.48989692693576214 loss_val : 0.5318318208679557
# EarlyStopping counter: 6 out of 20
# Epoch :  156 	 loss : 0.48853943711146713 loss_val : 0.5315412126481533
# Validation loss decreased (0.531068 --> 0.528219).  Saving model ...
# Epoch :  157 	 loss : 0.4866757235489786 loss_val : 0.5282187551259995
# Validation loss decreased (0.528219 --> 0.526708).  Saving model ...
# Epoch :  158 	 loss : 0.48408091040328144 loss_val : 0.5267080008983612
# Validation loss decreased (0.526708 --> 0.525598).  Saving model ...
# Epoch :  159 	 loss : 0.4826741099823266 loss_val : 0.52559779509902
# EarlyStopping counter: 1 out of 20
# Epoch :  160 	 loss : 0.4834894111379981 loss_val : 0.5294268980622292
# EarlyStopping counter: 2 out of 20
# Epoch :  161 	 loss : 0.4834912298247218 loss_val : 0.5309950850903988
# EarlyStopping counter: 3 out of 20
# Epoch :  162 	 loss : 0.48047609040513634 loss_val : 0.5298667564988137
# EarlyStopping counter: 4 out of 20
# Epoch :  163 	 loss : 0.4805397246032953 loss_val : 0.5341253831982613
# EarlyStopping counter: 5 out of 20
# Epoch :  164 	 loss : 0.48069065948948264 loss_val : 0.5277314994484186
# EarlyStopping counter: 6 out of 20
# Epoch :  165 	 loss : 0.4767543693073094 loss_val : 0.5293460261076689
# EarlyStopping counter: 7 out of 20
# Epoch :  166 	 loss : 0.47787859323434534 loss_val : 0.5377813246101141
# EarlyStopping counter: 8 out of 20
# Epoch :  167 	 loss : 0.4764230862259865 loss_val : 0.5292159799486399
# EarlyStopping counter: 9 out of 20
# Epoch :  168 	 loss : 0.47768129240721463 loss_val : 0.530457367002964
# EarlyStopping counter: 10 out of 20
# Epoch :  169 	 loss : 0.47440259614959357 loss_val : 0.5294498823583126
# EarlyStopping counter: 11 out of 20
# Epoch :  170 	 loss : 0.47624799543991686 loss_val : 0.5290415342897177
# EarlyStopping counter: 12 out of 20
# Epoch :  171 	 loss : 0.47204670920036734 loss_val : 0.5351091910153627
# EarlyStopping counter: 13 out of 20
# Epoch :  172 	 loss : 0.4718070645350963 loss_val : 0.5310636216774582
# EarlyStopping counter: 14 out of 20
# Epoch :  173 	 loss : 0.4734071884304285 loss_val : 0.5331885047256947
# EarlyStopping counter: 15 out of 20
# Epoch :  174 	 loss : 0.46961368443444373 loss_val : 0.536334490776062
# EarlyStopping counter: 16 out of 20
# Epoch :  175 	 loss : 0.46954790139570834 loss_val : 0.5348176978528499
# EarlyStopping counter: 17 out of 20
# Epoch :  176 	 loss : 0.4694297038950026 loss_val : 0.5363696988672018
# EarlyStopping counter: 18 out of 20
# Epoch :  177 	 loss : 0.46946573033928873 loss_val : 0.5282801738008857
# EarlyStopping counter: 19 out of 20
# Epoch :  178 	 loss : 0.4692059561610222 loss_val : 0.5413116797804832
# EarlyStopping counter: 20 out of 20
# Early stopping
# <ipython-input-14-3587fd0b847a>:21: RuntimeWarning: invalid value encountered in true_divide
#   SPred = np.divide( SPred, mask )

# %% [markdown]
# # one input with noise

# %%
# noise(eddy flux)
nre='00' # training data
nre2='00' # predict data
batchsize = 64
nlayer=0 # training layer
fileloc=data_dir+'preds/'

for kw in ['00']:
    if not os.path.exists(fileloc+kw):
        os.mkdir(fileloc+kw)
    filename=fileloc+'%s/'%(kw)

    for noise_level in [0.3,0.6,0.9,1.2]:
        for vn in ['div','uvq','grad']:#
            for f in ['empb','em','eb']:#
                for rni in range(30,50):
                    var1='psi'
                    print(kw,nre,var1,vn,f,rni,noise_level)
                    if kw == '00':
                        input_d = get_data(read_data(var1,nlayer,nre,f,noise_level))
                        if vn == 'div':
                            empb = get_data(read_data(vn,nlayer,nre,f,noise_level))
                        else:
                            gd_u = get_data(read_data(vn,nlayer,nre,f,noise_level)[0])
                            gd_v = get_data(read_data(vn,nlayer,nre,f,noise_level)[1])
                    else:
                        print('non')

                    if vn == 'div':
                        if not os.path.exists(filename+'%s/Pr_%s_%s_%s_%s_%s_%s.npy'%(nlayer,vn,f,nre2,var1,rni,"{:02}".format(int(noise_level * 10)))):
                            train_loader,val_loader, scalings=load_dataT(input_d,empb,rni,batchsize)
                            model = train_model(n_feature=1,n_out=1).to(device)
                            trainig_process(model,train_loader,val_loader)

                            for nly in range(1):
                                input_t = read_data(var1,nly,nre2,f,noise_level)
                                Spr=makePreds_1to1_all(input_t,scalings,model)
                                if not os.path.exists(filename+'%s'%(nly)):
                                    os.mkdir(filename+'%s'%(nly))
                                np.save(filename+'%s/Pr_%s_%s_%s_%s_%s_%s'%(nly,vn,f,nre2,var1,rni,"{:02}".format(int(noise_level * 10))),Spr)
                    else:
                        if not os.path.exists(filename+'%s/Pr_%s_%s_%s_%s_%s_%s.npz'%(nlayer,vn,f,nre2,var1,rni,"{:02}".format(int(noise_level * 10)))):
                            train_loader,val_loader, scalings1,scalings2=load_dataT2(input_d,gd_u,gd_v,rni,batchsize)
                            model2 = train_model(n_feature=1,n_out=2).to(device)
                            trainig_process(model2,train_loader,val_loader)

                            for nly in range(1):
                                input_t = read_data(var1,nly,nre2,f,noise_level)
                                Spr_u,Spr_v=makePreds_1to2_all(input_t,scalings1,scalings2,model2)
                                if not os.path.exists(filename+'%s'%(nly)):
                                    os.mkdir(filename+'%s'%(nly))
                                np.savez(filename+'%s/Pr_%s_%s_%s_%s_%s_%s'%(nly,vn,f,nre2,var1,rni,"{:02}".format(int(noise_level * 10))),Spr_u,Spr_v)
# Out:
# 00 00 psi div empb 30 0.3
# Validation loss decreased (inf --> 0.977832).  Saving model ...
# Epoch :  1 	 loss : 1.007630855590105 loss_val : 0.9778317153453827
# Validation loss decreased (0.977832 --> 0.974036).  Saving model ...
# Epoch :  2 	 loss : 1.0037577599287033 loss_val : 0.9740359783172607
# Validation loss decreased (0.974036 --> 0.965281).  Saving model ...
# Epoch :  3 	 loss : 0.9947006039321422 loss_val : 0.9652814984321594
# Validation loss decreased (0.965281 --> 0.963339).  Saving model ...
# Epoch :  4 	 loss : 0.9851163975894451 loss_val : 0.9633387058973313
# Validation loss decreased (0.963339 --> 0.961919).  Saving model ...
# Epoch :  5 	 loss : 0.981408878415823 loss_val : 0.9619192242622375
# Validation loss decreased (0.961919 --> 0.960165).  Saving model ...
# Epoch :  6 	 loss : 0.9785575114190579 loss_val : 0.96016546189785
# Validation loss decreased (0.960165 --> 0.958859).  Saving model ...
# Epoch :  7 	 loss : 0.9771972894668579 loss_val : 0.9588591188192368
# Validation loss decreased (0.958859 --> 0.957575).  Saving model ...
# Epoch :  8 	 loss : 0.9758286990225316 loss_val : 0.9575746715068817
# EarlyStopping counter: 1 out of 20
# Epoch :  9 	 loss : 0.9747871868312359 loss_val : 0.9579189836978912
# Validation loss decreased (0.957575 --> 0.956821).  Saving model ...
# Epoch :  10 	 loss : 0.9738618023693562 loss_val : 0.9568205267190933
# Validation loss decreased (0.956821 --> 0.955536).  Saving model ...
# Epoch :  11 	 loss : 0.9731455497443676 loss_val : 0.9555357724428177
# EarlyStopping counter: 1 out of 20
# Epoch :  12 	 loss : 0.9722116127610206 loss_val : 0.9561065912246705
# EarlyStopping counter: 2 out of 20
# Epoch :  13 	 loss : 0.9714600205421448 loss_val : 0.957015922665596
# Validation loss decreased (0.955536 --> 0.955182).  Saving model ...
# Epoch :  14 	 loss : 0.9706234380602836 loss_val : 0.9551815837621689
# Validation loss decreased (0.955182 --> 0.954007).  Saving model ...
# Epoch :  15 	 loss : 0.9705328531563282 loss_val : 0.9540072351694107
# Validation loss decreased (0.954007 --> 0.953910).  Saving model ...
# Epoch :  16 	 loss : 0.9693637073040009 loss_val : 0.9539103180170059
# Validation loss decreased (0.953910 --> 0.953323).  Saving model ...
# Epoch :  17 	 loss : 0.9687439225614071 loss_val : 0.9533231139183045
# EarlyStopping counter: 1 out of 20
# Epoch :  18 	 loss : 0.9683980576694011 loss_val : 0.9534625083208084
# Validation loss decreased (0.953323 --> 0.952970).  Saving model ...
# Epoch :  19 	 loss : 0.967915628105402 loss_val : 0.9529703795909882
# Validation loss decreased (0.952970 --> 0.952436).  Saving model ...
# Epoch :  20 	 loss : 0.9673770815134048 loss_val : 0.9524362981319427
# EarlyStopping counter: 1 out of 20
# Epoch :  21 	 loss : 0.9668318279087543 loss_val : 0.952915757894516
# EarlyStopping counter: 2 out of 20
# Epoch :  22 	 loss : 0.9661732763051987 loss_val : 0.9536883980035782
# EarlyStopping counter: 3 out of 20
# Epoch :  23 	 loss : 0.9658190988004207 loss_val : 0.9526211738586425
# Validation loss decreased (0.952436 --> 0.951940).  Saving model ...
# Epoch :  24 	 loss : 0.9656043067574501 loss_val : 0.9519398391246796
# EarlyStopping counter: 1 out of 20
# Epoch :  25 	 loss : 0.9648734934628009 loss_val : 0.9521320641040802
# EarlyStopping counter: 2 out of 20
# Epoch :  26 	 loss : 0.9646202996373177 loss_val : 0.952113276720047
# EarlyStopping counter: 3 out of 20
# Epoch :  27 	 loss : 0.9641164533793927 loss_val : 0.9528075516223907
# Validation loss decreased (0.951940 --> 0.951639).  Saving model ...
# Epoch :  28 	 loss : 0.9638352021574974 loss_val : 0.9516394793987274
# EarlyStopping counter: 1 out of 20
# Epoch :  29 	 loss : 0.9631938584148884 loss_val : 0.9516994893550873
# Validation loss decreased (0.951639 --> 0.951141).  Saving model ...
# Epoch :  30 	 loss : 0.9631476283073426 loss_val : 0.9511414170265198
# EarlyStopping counter: 1 out of 20
# Epoch :  31 	 loss : 0.962387566268444 loss_val : 0.9514255404472352
# EarlyStopping counter: 2 out of 20
# Epoch :  32 	 loss : 0.9620900087058544 loss_val : 0.9522643208503723
# Validation loss decreased (0.951141 --> 0.951026).  Saving model ...
# Epoch :  33 	 loss : 0.9620531603693963 loss_val : 0.951025640964508
# EarlyStopping counter: 1 out of 20
# Epoch :  34 	 loss : 0.9614076599478721 loss_val : 0.951206722855568
# Validation loss decreased (0.951026 --> 0.951012).  Saving model ...
# Epoch :  35 	 loss : 0.9610875949263573 loss_val : 0.9510122567415238
# Validation loss decreased (0.951012 --> 0.950302).  Saving model ...
# Epoch :  36 	 loss : 0.9608946174383164 loss_val : 0.9503024399280549
# EarlyStopping counter: 1 out of 20
# Epoch :  37 	 loss : 0.960592720657587 loss_val : 0.9514599055051803
# EarlyStopping counter: 2 out of 20
# Epoch :  38 	 loss : 0.959975178539753 loss_val : 0.9505431145429611
# Validation loss decreased (0.950302 --> 0.950143).  Saving model ...
# Epoch :  39 	 loss : 0.9597643755376339 loss_val : 0.9501428127288818
# EarlyStopping counter: 1 out of 20
# Epoch :  40 	 loss : 0.9595559529960156 loss_val : 0.9502428770065308
# EarlyStopping counter: 2 out of 20
# Epoch :  41 	 loss : 0.9587407432496547 loss_val : 0.9505635052919388
# Validation loss decreased (0.950143 --> 0.949626).  Saving model ...
# Epoch :  42 	 loss : 0.9587801344692707 loss_val : 0.9496259033679962
# EarlyStopping counter: 1 out of 20
# Epoch :  43 	 loss : 0.9578415103256702 loss_val : 0.9501990646123886
# EarlyStopping counter: 2 out of 20
# Epoch :  44 	 loss : 0.9577451772987843 loss_val : 0.9496845364570617
# EarlyStopping counter: 3 out of 20
# Epoch :  45 	 loss : 0.9576607339084149 loss_val : 0.9497892707586288
# EarlyStopping counter: 4 out of 20
# Epoch :  46 	 loss : 0.9574428431689739 loss_val : 0.9505470186471939
# Validation loss decreased (0.949626 --> 0.949525).  Saving model ...
# Epoch :  47 	 loss : 0.9567703731358052 loss_val : 0.9495252370834351
# EarlyStopping counter: 1 out of 20
# Epoch :  48 	 loss : 0.9562580369412899 loss_val : 0.9499808311462402
# EarlyStopping counter: 2 out of 20
# Epoch :  49 	 loss : 0.9561241492629051 loss_val : 0.9504196226596833
# EarlyStopping counter: 3 out of 20
# Epoch :  50 	 loss : 0.9554392956197262 loss_val : 0.9500274807214737
# EarlyStopping counter: 4 out of 20
# Epoch :  51 	 loss : 0.9551098585128784 loss_val : 0.9503253728151322
# EarlyStopping counter: 5 out of 20
# Epoch :  52 	 loss : 0.9551673457026482 loss_val : 0.9502576380968094
# Validation loss decreased (0.949525 --> 0.949439).  Saving model ...
# Epoch :  53 	 loss : 0.9547381162643432 loss_val : 0.9494393736124038
# EarlyStopping counter: 1 out of 20
# Epoch :  54 	 loss : 0.9543365895748138 loss_val : 0.94957275390625
# EarlyStopping counter: 2 out of 20
# Epoch :  55 	 loss : 0.9540470033884049 loss_val : 0.9497435331344605
# Validation loss decreased (0.949439 --> 0.949306).  Saving model ...
# Epoch :  56 	 loss : 0.9539143227040767 loss_val : 0.9493056327104569
# EarlyStopping counter: 1 out of 20
# Epoch :  57 	 loss : 0.9535153158009052 loss_val : 0.9493054449558258
# EarlyStopping counter: 2 out of 20
# Epoch :  58 	 loss : 0.9532074235379696 loss_val : 0.9493887215852738
# EarlyStopping counter: 3 out of 20
# Epoch :  59 	 loss : 0.9528111070394516 loss_val : 0.9495003581047058
# Validation loss decreased (0.949306 --> 0.949203).  Saving model ...
# Epoch :  60 	 loss : 0.952893789112568 loss_val : 0.9492029011249542
# Validation loss decreased (0.949203 --> 0.949141).  Saving model ...
# Epoch :  61 	 loss : 0.9521468371152878 loss_val : 0.9491414874792099
# Validation loss decreased (0.949141 --> 0.948956).  Saving model ...
# Epoch :  62 	 loss : 0.9517964914441108 loss_val : 0.9489560484886169
# Validation loss decreased (0.948956 --> 0.948312).  Saving model ...
# Epoch :  63 	 loss : 0.9518019467592239 loss_val : 0.9483118712902069
# EarlyStopping counter: 1 out of 20
# Epoch :  64 	 loss : 0.9512620590627193 loss_val : 0.9487645119428635
# EarlyStopping counter: 2 out of 20
# Epoch :  65 	 loss : 0.9508548311889171 loss_val : 0.9499875694513321
# EarlyStopping counter: 3 out of 20
# Epoch :  66 	 loss : 0.9504158549010754 loss_val : 0.9489288717508316
# EarlyStopping counter: 4 out of 20
# Epoch :  67 	 loss : 0.9507360264658928 loss_val : 0.9491836965084076
# EarlyStopping counter: 5 out of 20
# Epoch :  68 	 loss : 0.950027035176754 loss_val : 0.9492730230093003
# EarlyStopping counter: 6 out of 20
# Epoch :  69 	 loss : 0.9503158889710903 loss_val : 0.948946887254715
# EarlyStopping counter: 7 out of 20
# Epoch :  70 	 loss : 0.9499256394803524 loss_val : 0.9494808077812195
# EarlyStopping counter: 8 out of 20
# Epoch :  71 	 loss : 0.9495767973363399 loss_val : 0.9497681349515915
# EarlyStopping counter: 9 out of 20
# Epoch :  72 	 loss : 0.9492193177342415 loss_val : 0.9496486335992813
# EarlyStopping counter: 10 out of 20
# Epoch :  73 	 loss : 0.9489691741764545 loss_val : 0.9488565176725388
# EarlyStopping counter: 11 out of 20
# Epoch :  74 	 loss : 0.9490848921239377 loss_val : 0.949037891626358
# EarlyStopping counter: 12 out of 20
# Epoch :  75 	 loss : 0.9481564663350582 loss_val : 0.9486193358898163
# EarlyStopping counter: 13 out of 20
# Epoch :  76 	 loss : 0.9480429030954838 loss_val : 0.9486712574958801
# EarlyStopping counter: 14 out of 20
# Epoch :  77 	 loss : 0.9479072198271752 loss_val : 0.9488599270582199
# EarlyStopping counter: 15 out of 20
# Epoch :  78 	 loss : 0.9478116758167744 loss_val : 0.949794790148735
# EarlyStopping counter: 16 out of 20
# Epoch :  79 	 loss : 0.9475001685321331 loss_val : 0.94840407371521
# EarlyStopping counter: 17 out of 20
# Epoch :  80 	 loss : 0.9468043260276318 loss_val : 0.948527255654335
# EarlyStopping counter: 18 out of 20
# Epoch :  81 	 loss : 0.9465304777026177 loss_val : 0.9487518101930619
# EarlyStopping counter: 19 out of 20
# Epoch :  82 	 loss : 0.9463810712099076 loss_val : 0.9496490240097046
# EarlyStopping counter: 20 out of 20
# Early stopping
# <ipython-input-15-b6bf347978df>:21: RuntimeWarning: invalid value encountered in true_divide
#   SPred = np.divide( SPred, mask )

# %% [markdown]
# # plot

# %%
lm=30
plt.imshow(Spr,origin='lower',cmap='RdBu_r',vmax=lm,vmin=-lm)#
plt.colorbar()
aa=plt.title(r'Pred $ \nabla \cdot \overline{u^{\prime} q^{\prime}} $',fontsize=15)
